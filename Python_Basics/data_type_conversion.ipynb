# %%
X = 10
print(X)
print(type(X))
# Out:
# 10
# <class 'int'>

# %%
x = float(X)
print(x)
print(type(x))
# Out:
# 10.0
# <class 'float'>

# %%
yY = 10.2634
print(yY)
print(type(yY))
# Out:
# 10.2634
# <class 'float'>

# %%
y = int(yY)
print(y)
print(type(y))
# Out:
# 10
# <class 'int'>

# %%
z = 24169956
print(z)
print(type(z))
# Out:
# 24169956
# <class 'int'>

# %%
Z = str(z)
print(Z)   
print(type(Z))
# Out:
# 24169956
# <class 'str'>

# %%
age = input("What is your age? ")
print(age)  
print(type(age))
# Out:
# 26
# <class 'str'>

# %%
age_int = int(input("What is your age? "))
print(age_int)
print(type(age_int))
# Out:
# 26
# <class 'int'>
